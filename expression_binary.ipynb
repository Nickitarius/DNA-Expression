# %%
import numpy as np
import bisect


def read_input(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()

    for i in range(len(lines)):
        lines[i] = lines[i].replace("\n", "")

    first_line = lines[0].split(" ")
    first_line = [int(numeric_string) for numeric_string in first_line]
    n = first_line[0]
    m = first_line[1]

    genes = []
    for i in range(1, 1+n):
        line = lines[i].split(" ")
        line = [int(numeric_string) for numeric_string in line]
        genes.append(line)

    reads = []
    for i in range(1+n, 1+m+n):
        line = lines[i].split(" ")
        line = [int(numeric_string) for numeric_string in line]
        reads.append(line)

    return n, m, genes, reads

# %%
def binarySearchCustom(arr, x, xMoreLessEqual='equal'):
    low = 0
    high = len(arr) - 1
    mid = 0
    isXLower = True

    while low <= high:
        mid = (high + low) // 2

        # If x is greater, ignore left half
        if arr[mid] < x:
            low = mid + 1

        # If x is smaller, ignore right half
        elif arr[mid] > x:
            high = mid - 1

        # means x is present at mid
        else:
            print(f'{arr[mid]} {xMoreLessEqual} than {x} mid {mid}')
            return mid

    if (arr[mid] > x):
        isXLower = True
    else:
        isXLower = False
        # if (mid-1 >= 0):

    print(
        f'Found x={x} must be {xMoreLessEqual} than arr[mid]={arr[mid]} mid {mid} isXLower {isXLower}')
    # If we reach here, then the element was not present
    if (isXLower and (xMoreLessEqual == 'less')):
        return mid
    if ((not isXLower) and (xMoreLessEqual == 'more')):
        return mid
    if (xMoreLessEqual == 'more' and isXLower):
        return 0
    return -1

# %%
def calculateExpressions(filename):
    n, m, genes, reads = read_input(filename)

    intersectionsReads = []
    intersectionsGenes = []

    for i in range(n):
        intersectionsReads.append([])

    for i in range(m):
        intersectionsGenes.append([])

    # Iterate over reads
    for rd in range(m):
        # Iterate over each read interval
        for i in range(0, len(reads[rd]), 2):
            # Iterate over genes
            for g in range(n):
                L = binarySearchCustom(genes[g], reads[rd][i], 'more')
                R = binarySearchCustom(genes[g], reads[rd][i+1], 'less')

                if (R >= len(genes[g])):
                    R -= 1

                # elif (R > 0 and not R == L):
                #     R -= 1
                # if (genes[g][R] < reads[rd][i+1]):
                #     R -= 1

                # print(genes[g])
                # if (L < len(genes[g]) and R < len(genes[g])):
                #     L = genes[g][L]
                #     R = genes[g][R]

                # print(g)
                print(f'g {g} rd {rd} i {i}')
                print(f'L {L} R {R}\n')
                # isLeftIn = reads[rd][i] <= genes[g][R]  # and \
                # # reads[r][i+1] <= genes[g][R]
                # isRightIn = reads[rd][i + 1] >= genes[g][L]  # and \
                # # reads[r][i] <= genes[g][L]
                # isIncluding = reads[rd][i] <= genes[g][L] and \
                #     reads[rd][i+1] >= genes[g][R]
                # or isIncluding and L>=0):  isLeftIn or isRightIn or   ((L <= R or R % 2 == 1) and L == R+1)
                # if ((L <= R or R % 2 == 1 and (L == R + 1)) and (R >= 0 and L >= 0)):
                isValid = R >= 0 and L >= 0
                isIntersect = (L <= R or R % 2 == 1 and L == R + 1)
                if isValid and isIntersect:
                    # print(f'{L} {R}\n')
                    # print('yep\n')
                    intersectionsReads[g].append(rd)
                    intersectionsGenes[rd].append(g)

    # print(f'intersectionsGenes: {intersectionsGenes}')
    for i in range(n):
        print(f'intersectionsReads {i}: {intersectionsReads[i]}')

    print(intersectionsGenes)

    reads = []
    for g in range(n):
        temp = []
        for rd in range(len(intersectionsGenes)):
            if (intersectionsGenes[rd] == g):
                temp.append(intersectionsReads[rd])

        reads.append(np.unique(temp).tolist())

    readsOccurencesCounts = np.zeros(m)
    for i in range(m):
        for g in reads:
            if (g.__contains__(i)):
                readsOccurencesCounts[i] = readsOccurencesCounts[i]+1

    for i in range(m):
        if (readsOccurencesCounts[i] > 1):
            for rd in reads:
                if (rd.__contains__(i)):
                    rd.remove(i)

    uniqueReadsPerGene = np.zeros(n)
    for i in range(n):
        uniqueReadsPerGene[i] = len(reads[i])

    return uniqueReadsPerGene

# %%
u = calculateExpressions('./tests-easy/1')
# Out:
# 1100 more than 1100 mid 1
# Found x=1160 must be less than arr[mid]=2000 mid 2 isXLower True
# g 0 rd 0 i 0
# L 1 R 2
#
# Found x=1100 must be more than arr[mid]=3000 mid 0 isXLower True
# Found x=1160 must be less than arr[mid]=3000 mid 0 isXLower True
# g 1 rd 0 i 0
# L -1 R 0
#
# Found x=1190 must be more than arr[mid]=2000 mid 2 isXLower True
# Found x=1200 must be less than arr[mid]=2000 mid 2 isXLower True
# g 0 rd 1 i 0
# L -1 R 2
#
# Found x=1190 must be more than arr[mid]=3000 mid 0 isXLower True
# Found x=1200 must be less than arr[mid]=3000 mid 0 isXLower True
# g 1 rd 1 i 0
# L -1 R 0
#
# 2000 more than 2000 mid 2
# Found x=2050 must be less than arr[mid]=2400 mid 3 isXLower True
# g 0 rd 1 i 2
# L 2 R 3
#
# Found x=2000 must be more than arr[mid]=3000 mid 0 isXLower True
# Found x=2050 must be less than arr[mid]=3000 mid 0 isXLower True
# g 1 rd 1 i 2
# L -1 R 0
#
# Found x=3280 must be more than arr[mid]=2400 mid 3 isXLower False
# Found x=3300 must be less than arr[mid]=2400 mid 3 isXLower False
# g 0 rd 2 i 0
# L 3 R -1
#
# Found x=3280 must be more than arr[mid]=3300 mid 1 isXLower True
# 3300 less than 3300 mid 1
# g 1 rd 2 i 0
# L -1 R 1
#
# Found x=3500 must be more than arr[mid]=2400 mid 3 isXLower False
# Found x=3550 must be less than arr[mid]=2400 mid 3 isXLower False
# g 0 rd 2 i 2
# L 3 R -1
#
# Found x=3500 must be more than arr[mid]=3300 mid 1 isXLower False
# Found x=3550 must be less than arr[mid]=3300 mid 1 isXLower False
# g 1 rd 2 i 2
# L 1 R -1
#
# Found x=1500 must be more than arr[mid]=2000 mid 2 isXLower True
# Found x=1560 must be less than arr[mid]=2000 mid 2 isXLower True
# g 0 rd 3 i 0
# L -1 R 2
#
# Found x=1500 must be more than arr[mid]=3000 mid 0 isXLower True
# Found x=1560 must be less than arr[mid]=3000 mid 0 isXLower True
# g 1 rd 3 i 0
# L -1 R 0
#
# intersectionsReads 0: [0, 1]
# intersectionsReads 1: []
# [[0], [0], [], []]

# %%
for i in range(1, 16, 1):
    with open("./results/"+str(i), 'w') as f:
        for rd in res[i-1]:
            f.write(str(int(rd)) + '\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Programming\IPYNB\BioInf\DNA Expression\expression_binary.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/e%3A/Programming/IPYNB/BioInf/DNA%20Expression/expression_binary.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> for i in range(1, 16, 1):
#       <a href='vscode-notebook-cell:/e%3A/Programming/IPYNB/BioInf/DNA%20Expression/expression_binary.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     with open("./results/"+str(i), 'w') as f:
# ----> <a href='vscode-notebook-cell:/e%3A/Programming/IPYNB/BioInf/DNA%20Expression/expression_binary.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>         for rd in res[i-1]:
#       <a href='vscode-notebook-cell:/e%3A/Programming/IPYNB/BioInf/DNA%20Expression/expression_binary.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>             f.write(str(int(rd)) + '\n')
#
# NameError: name 'res' is not defined

# %%
def read_console_input():
    in1 = input()
    first_line = in1.split(" ")
    first_line = [int(numeric_string) for numeric_string in first_line]
    n = first_line[0]
    m = first_line[1]

    genes = []
    for i in range(1, 1+n):
        l = input()
        line = l.split(" ")
        line = [int(numeric_string) for numeric_string in line]
        genes.append(line)

    reads = []
    for i in range(1+n, 1+m+n):
        l = input()
        line = l.split(" ")
        line = [int(numeric_string) for numeric_string in line]
        reads.append(line)

    return n, m, genes, reads


n, m, genes, reads = read_console_input()
# Out:
# 2 4
# [[1100, 1100, 2000, 2400], [3000, 3300]]
# [[1100, 1160], [1190, 1200, 2000, 2050], [3280, 3300, 3500, 3550], [1500, 1560]]

# %%
# Для Stepik

# put your python code here
import numpy as np


def read_console_input():
    in1 = input()
    first_line = in1.split(" ")
    first_line = [int(numeric_string) for numeric_string in first_line]
    n = first_line[0]
    m = first_line[1]

    genes = []
    for i in range(1, 1+n):
        l = input()
        line = l.split(" ")
        line = [int(numeric_string) for numeric_string in line]
        genes.append(line)

    reads = []
    for i in range(1+n, 1+m+n):
        l = input()
        line = l.split(" ")
        line = [int(numeric_string) for numeric_string in line]
        reads.append(line)

    return n, m, genes, reads


def calculateExpressions():
    n, m, genes, reads = read_console_input()

    intersectionsReads = []
    intersectionsGenes = []
    # Iterate over genes
    for i in range(n):
        # Iterate over each gene interval
        for j in range(0, len(genes[i]), 2):
            # Iterate over reads
            for k in range(m):
                # Iterate over each read interval
                for r in range(0, len(reads[k]), 2):
                    isLeftIn = reads[k][r] >= genes[i][j] and \
                        reads[k][r] <= genes[i][j+1]
                    isRightIn = reads[k][r + 1] >= genes[i][j] and \
                        reads[k][r+1] <= genes[i][j+1]
                    isIncluding = reads[k][r] <= genes[i][j] and \
                        reads[k][r + 1] >= genes[i][j+1]
                    if (isLeftIn or isRightIn or isIncluding):
                        intersectionsGenes.append(i)
                        intersectionsReads.append(k)

    reads = []
    for g in range(n):
        temp = []
        for r in range(len(intersectionsGenes)):
            if (intersectionsGenes[r] == g):
                temp.append(intersectionsReads[r])

        reads.append(np.unique(temp).tolist())

    readsOccurencesCounts = np.zeros(m)
    for i in range(m):
        for g in reads:
            if (g.__contains__(i)):
                readsOccurencesCounts[i] = readsOccurencesCounts[i]+1

    for i in range(m):
        if (readsOccurencesCounts[i] > 1):
            for r in reads:
                if (r.__contains__(i)):
                    r.remove(i)

    uniqueReadsPerGene = np.zeros(n)
    for i in range(n):
        uniqueReadsPerGene[i] = len(reads[i])

    return uniqueReadsPerGene


reads = calculateExpressions()

for rd in reads:
    print(int(rd))
# Out:
# 2
# 1
